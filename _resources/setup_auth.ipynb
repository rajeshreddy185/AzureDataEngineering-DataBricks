# %%
# 1. Setup the credentials
storage_account_name = "rjdatalakestorage01" 
storage_key = dbutils.secrets.get(scope='adlsgen2storageaccesskey', key='storageadlsgen2accesskey')
container_name = "databrickscontainer01"
# 2. Tell Spark to use this key
spark.conf.set(
    f"fs.azure.account.key.{storage_account_name}.dfs.core.windows.net", 
    storage_key
)
